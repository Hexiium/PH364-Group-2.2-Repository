# %% [markdown]
# **Midterm Module Showcase**
# **PH 364 – Spring 2026**
#
# Goals:
# - Familiarize yourself with a new python library and one of it’s modules.
# - Explain that module in a way your peers can understand.
# - Connect your chosen module to the practice of solving physics problems.
#
# For your midterm project you’ll choose a module from a Python library that we haven't used in class. The library should be explicitly relevant to physics. Example libraries you can choose from:
# - [Astropy](https://learn.astropy.org/)
# - [Qiskit](https://quantum.cloud.ibm.com/docs/en/guides)
# - [QuTip](https://qutip.org/qutip-tutorials/)
# - [MDTraj](https://mdtraj.org/1.9.4/examples/introduction.html)
# - Or any other library with instructor approval, don’t hesitate to ask if you find a library you think might be interesting.
#
# Skim through the documentation for each library to narrow your choices down. Then once you’ve chosen your module go through its documentation more thoroughly, and follow any tutorial materials provided in the documentation to learn how it works. Feel free to also look up tutorials elsewhere on the internet, just make sure to include a citation to them.
#
# Once you've familiarized yourself with how your chosen module works, write a brief high-level description of it in your own words.
#
# Then come up with a physics question you think your chosen module could help you understand in some way. It doesn't have to be something your module could solve completely or comprehensively, just something you can get some insight on. Explain how the module could help you develop that insight and understanding.
#
# For the last part of this project you’ll then write some code that shows how the module helped you understand your chosen physics problem. Include that code as an example, and explain how and why you wrote it as you did.
#
# In summary, the document you turn in should have:
# - The name of your chosen library and a module within that library.
# - Links to any documentation and tutorials about that library that you relied upon.
# - A brief overview of your chosen library and module.
# - A physics question you want to use your chosen module to help you answer and how you think it can do so.
# - An example of you using your chosen module to gain insight into your chosen physics question, and an explanation of what you did. The code and the narrative explanation can be woven together in multiple code/markdown cells.

# %% [markdown]
# Work in a .ipynb to show both your textual explanations and your code in the same file. After you are done...
#
# Download your work as an HTML file, by selecting: `File` --> `Save and Export Notebook As...` --> `HTML` inside the JupyterHub interface (don't select your browser's File menu).
#
# Open your downloaded file to ensure the contents look okay, then submit it on Canvas.

# %% [markdown]
# From the Python Library, I have chosen SymPy, which deals with the computation of mathematical objects symbolically. With SymPy, it will give you exact solutions to any math questions instead of approximate or unclear answers. For example, let’s say we wanted to find 8 using SymPy. The answer will end up giving you a long rational number, which is not exact. In order for it to be exact, you would have to import SymPy into the code, and now the answer will give you 22. SymPy can simplify expressions, compute derivatives, integrals, and limits, solve equations, work with matrices, and much more. For my module, I have chosen symbols, which defines variables, acting as placeholders for unknown values in mathematical expressions. It also enables algebraic simplification, equation solving, and exact analytical expressions used in physics problem solving.
#
# https://docs.sympy.org/latest/tutorials/physics/mechanics/rollingdisc_example_kane_constraints.html
#
# https://scipy-lectures.org/packages/sympy.html#calculus
